# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
def coastline_scaling(pr, distance):
    return pr / ((0.1*distance) + 1)

def coastline_scaling2(pr, distance):
    return pr - pr * 0.1 * distance

distance = np.arange(50)
pr = 10

plt.plot(distance, coastline_scaling(pr, distance))
#plt.plot(distance, coastline_scaling2(pr, distance))
