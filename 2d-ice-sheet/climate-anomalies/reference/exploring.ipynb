# %%
import cartopy.io.shapereader as shpreader
import cartopy.crs as ccrs
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
# figure beautification
sns.set_theme(
    style='whitegrid',
    palette='deep',
    color_codes=True # access seaborn colors by changing matplotlib color shorthands
)
# %config InlineBackend.figure_format = 'retina'

# %%
# load data
data = np.load('simulation-data.npz')
for arr in data.files:
    #globals()[arr] = data[arr]
    print(arr)
# Out:
# z
# h
# smb
# xlon
# ylat
# nt
# seamask

# %%
# import data
#z = data['z']
#smb = data['smb']
#xlon = data['xlon']
#ylat = data['ylat']
#nt = data['nt']
#seamask = data['seamask']

# import ice thickness and convert to ice volume in km^3
h = np.sum(data['h'][:10000], axis=(1,2)) * 40 * 40 / 1e3

# %%
np.shape(h)
# Out:
# (10000,)

# %%
x = np.arange(10000)
plt.plot(x, h)

# %%
h[-1] - h[0]
# Out:
# 3322860.6921100765
